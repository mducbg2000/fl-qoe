# %%
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
models = json.load(open('model_compare.json','r'))
x = models['num_clients']

# %%
plt.plot(models['lstm'], 'o-r', label='lstm')
plt.plot(models['bidirectional'], 'o-b', label='bidirectional lstm')
plt.plot(models['gru'], 'o-g', label='gru')

xi = list(range(len(x)))
plt.xticks(xi, x)

plt.xlabel('Number of Client')
plt.ylabel('MSE')

plt.legend()
plt.show()

# %%
data = json.load(open('fed_compare.json','r'))
x = data['num_clients']

# %%
plt.plot(data['bidirectional-lstm-2']['central'], 'o-r', label='Central')
plt.plot(data['bidirectional-lstm-2']['FedAvg'], 'o-b', label='FedAvg')
xi = list(range(len(x)))
plt.xticks(xi, x)

plt.xlabel('Number of Client')
plt.ylabel('MSE')

plt.title("Pokemon dataset")
plt.legend()
plt.show()
